# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def successor(x):
    s = x
    return s
def multiply(x,y):
    return x*y -2

# %%
multiplier = 10
N = 1000
x_list = np.linspace(0,10,N)
def y(x):
    g = np.cos(2*x)**2
    f = -4*np.sin(x)*np.cos(x) 
    return g + f
y_list = []
for x in x_list:
    y_list.append(y(x))
plt.plot(x_list,y_list)
