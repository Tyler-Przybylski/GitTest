# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def successor(x):
    s = x + 1
    return s
def multiply(x,y):
    return x*y

# %%
multiplier = 10
N = 100
x_list = np.linspace(0,10,N)
def y(x):
    g = np.cos(2*x)**2
    f = -4*np.sin(x)*np.cos(x) 
    return g + f
y_list = []
for x in x_list:
    y_list.append(multiplier * y(x))
plt.plot(x_list,y_list)
